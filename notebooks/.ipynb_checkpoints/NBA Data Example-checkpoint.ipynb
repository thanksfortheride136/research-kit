# %% [markdown]
# # What Predicts Scoring in the NBA?
# ---

# %% [markdown]
# I think the scoring will correlate to more time played as well as more games played. However there most likely be another metric because some players will score more when put in for the same amount of time. Are higher scorers attempting more or less 2 pointers? All must be considered.

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
# Replace with your file name
df = pd.read_csv("nba_player_stats_2026.csv")

# %% [markdown]
# # Headings Key
# PLAYER_ID → Unique player identifier
#
# RANK → Player’s rank in the dataset
#
# PLAYER → Player name
#
# TEAM_ID → Unique team identifier
# TEAM → Team abbreviation
#
# GP → Games played
#
# MIN → Minutes played
#
# FGM → Field goals made
#
# FGA → Field goals attempted
#
# FG_PCT → Field goal percentage
#
# FG3M → 3-point field goals made
#
# FG3A → 3-point field goals attempted
#
# FG3_PCT → 3-point percentage
#
# FTM → Free throws made
#
# FTA → Free throws attempted
#
# FT_PCT → Free throw percentage
#
# OREB → Offensive rebounds
#
# DREB → Defensive rebounds
#
# REB → Total rebounds
#
# AST → Assists
#
# STL → Steals
#
# BLK → Blocks
#
# TOV → Turnovers
#
# PF → Personal fouls
#
# PTS → Points scored
#
# EFF → Overall efficiency rating
#
# AST_TOV → Assist-to-turnover ratio
#
# STL_TOV → Steal-to-turnover ratio

# %% [markdown]
# # Calculate 2 point attempts:
#
# 2PT Made = FGM - FG3M
#
# 2PT Attempted = FGA - FG3A

# %%
df.columns
# Out:
# Index(['PLAYER_ID', 'RANK', 'PLAYER', 'TEAM_ID', 'TEAM', 'GP', 'MIN', 'FGM',
#        'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT',
#        'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'EFF',
#        'AST_TOV', 'STL_TOV'],
#       dtype='str')

# %%
df.head()
# Out:
#    PLAYER_ID  RANK                   PLAYER     TEAM_ID TEAM  GP   MIN  FGM  \
# 0    1629029     1              Luka Dončić  1610612747  LAL  64  2289  693
# 1    1628983     2  Shai Gilgeous-Alexander  1610612760  OKC  68  2259  731
# 2    1627759     3             Jaylen Brown  1610612738  BOS  71  2443  736
# 3     201142     4             Kevin Durant  1610612745  HOU  78  2840  716
# 4    1630178     5             Tyrese Maxey  1610612755  PHI  70  2661  694
#
#     FGA  FG_PCT  ...  REB  AST  STL  BLK  TOV   PF   PTS   EFF  AST_TOV  \
# 0  1457   0.476  ...  495  530  105   34  255  153  2143  2146     2.08
# 1  1321   0.553  ...  292  448   95   52  151  139  2117  2189     2.97
# 2  1543   0.477  ...  492  364   72   27  259  191  2038  1817     1.41
# 3  1376   0.520  ...  426  372   62   71  246  142  2026  1992     1.51
# 4  1501   0.462  ...  290  461  130   55  171  151  1980  1893     2.70
#
#    STL_TOV
# 0     0.41
# 1     0.63
# 2     0.28
# 3     0.25
# 4     0.76
# ...

# %%
lakers_roster = df[df["TEAM"] == "LAL"].sort_values(by="PTS", ascending=False)

# %%
lakers_roster.head(20)
# Out:
#      PLAYER_ID  RANK             PLAYER     TEAM_ID TEAM  GP   MIN  FGM   FGA  \
# 0      1629029     1        Luka Dončić  1610612747  LAL  64  2289  693  1457
# 46        2544    47       LeBron James  1610612747  LAL  60  1989  473   919
# 50     1630559    51      Austin Reaves  1610612747  LAL  51  1762  373   762
# 103    1629028   104      Deandre Ayton  1610612747  LAL  72  1958  403   601
# 137    1629060   138      Rui Hachimura  1610612747  LAL  68  1927  307   597
# 163    1631222   164       Jake LaRavia  1610612747  LAL  82  2061  240   523
# 171    1628379   172       Luke Kennard  1610612747  LAL  78  1681  236   443
# 198     203935   199       Marcus Smart  1610612747  LAL  62  1769  188   476
# 238    1629637   239       Jaxson Hayes  1610612747  LAL  66  1207  198   262
# 331    1629020   332  Jarred Vanderbilt  1610612747  LAL  65  1128  113   240
# 363    1642261   364      Dalton Knecht  1610612747  LAL  54   553   87   191
# ...
